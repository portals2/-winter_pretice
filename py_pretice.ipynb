# %%
#22-01-03
wei = 78.3
wei
wei = 99.99
print(wei)

y = 100
x = 100
print(x, y)

# %%
a= 'hello world'
print(len(a))

b= 'asdasdasd'
print(a+b)

# %%
# import turtle

# turtle.setup(width=600, height=600)
# t= turtle.Turtle()
# t.shape("turtle")

# input("pes ant key to exit")

a = 100000000 * ((1+0.03)**5)
print(a)

# %%
print(type(" "))

print(0.1+0.1+0.1 == 0.3)

0.1+0.1+0.1

# %%
# x= int(input("asd"))
# y= int(input("asd"))
# s= x+y
# print(s)
# print((x+y+s), "x={0}, y={1}".format(x,y))

x= input("asd")
y= input("asd")
z= input("asd")
k= input("asd")
j= input("asd")


print("오늘은 {0}에서 야구경기가 열렸습니다.\n{1}와 {2}시합 {3}의 활약 \n{1}가 {2}를 {4}로 승리".format(x,y,z,k,j))

# %%
#22-01-04
p = 40
q = 60
print(p/q)
print(p%q)

num = int(input("sec"))
m = num // 60
h = m // 60
hour_ = h % 60
min_ = m % 60
sec_ = num % 60
day_ = h // 24
print(day_, "d", hour_, "h", min_, "m", sec_, "s")

# %%
a = int(input("asd"))
b = float(input("asd"))
c = int(input("asd"))

print(a*(1+b)**c)

# %%
bottom = 2
height = 1

print((bottom **2 + height **2)** 0.5)

F = 100
print((F-32)*0.55)

bottom += 1
bottom > height

height and bottom != height
bin(1 | 1) #비트 연산자 (압축에 관한 코드에 사용)

print((bottom + bottom + height) / 3)
bin(12)

# %%
#매핑, for문을 이용하지 않고 한번에 값을 준다.
#뒤에 .split()은 띄어있는 부분을 보고 입력값을 분할 한다. 
x, y, z = map(int, input("asd").split())

# %%
import random
list  = [10,20, 30, 40, 50]
random.shuffle(list) #섞기
print(list)

print(random.choice(list)) #렌덤 선택

# %%
#22-01-05
i= 0
if (i>30):
    print("no")
else:
    print("yes")
    if (i < 10):
        print("but more")

# %%
#터틀을 이용한 if문 활용 방법
import turtle
t = turtle.Turtle()
t.shape("turtle")

t.penup()

t.goto(100, 100)
t.write("양수")
t.goto(100, 0)
t.write("0")
t.goto(100, -100)
t.write("음수")

t.goto(0, 0)
t,turtle.pendown()

s = turtle.textinput("게임","숫자")
n = int(s)

turtle.done()

# %%
for i in "Hello":
    print(i) 

for i in range(1, 10):
    print(9*i)

a = list(range(10)) #range와 list의 활용성
# k = []
# k.append(range(10)) #range(10)을 "range(0, 10)"으로 인식함
print(a[0]) 


for i in range(10, 0, -1):
    print(i)

# %%
import turtle
t = turtle.Turtle()
t.shape("turtle")

n = 24

for i in range(n):
    t.forward(100 / (n * 0.3))
    t.left()
    
turtle.done()

# %%
import turtle
import random as rm

t = turtle.Turtle()
t.shape("turtle")
t.penup()

a = [23, 56, 75, 76, 45]
b = (20, 60, 120, 45)



while(True):
    x = rm.randrange(-250, -10)
    y = rm.randrange(-250, -10)
    
    t.
    t.goto(x, y)
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8844/1677324485.py in <module>
#      16
#      17
# ---> 18     t.goto(x, y)
#      19
#      20
#
# ~\AppData\Local\Programs\Python\Python39\lib\turtle.py in goto(self, x, y)
#    1775             self._goto(Vec2D(*x))
#    1776         else:
# -> 1777             self._goto(Vec2D(x, y))
#    1778
#    1779     def home(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\turtle.py in _goto(self, end)
#    3178                                      (start, self._position),
#    3179                                      self._pencolor, self._pensize, top)
# -> 3180                 self._update()
#    3181             if self._drawing:
#    3182                 screen._drawline(self.drawingLineItem, ((0, 0), (0, 0)),
#
# ~\AppData\Local\Programs\Python\Python39\lib\turtle.py in _update(self)
# ...

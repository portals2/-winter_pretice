# %%
wei = 78.3
wei
wei = 99.99
print(wei)

y = 100
x = 100
print(x, y)
# Out:
# 99.99
# 100 100

# %%
a= 'hello world'
print(len(a))

b= 'asdasdasd'
print(a+b)
# Out:
# 11
# hello worldasdasdasd

# %%
# import turtle

# turtle.setup(width=600, height=600)
# t= turtle.Turtle()
# t.shape("turtle")

# input("pes ant key to exit")

a = 100000000 * ((1+0.03)**5)
print(a)

# %%
print(type(" "))

print(0.1+0.1+0.1 == 0.3)

0.1+0.1+0.1
# Out:
# <class 'str'>
# False
# 0.30000000000000004

# %%
# x= int(input("asd"))
# y= int(input("asd"))
# s= x+y
# print(s)
# print((x+y+s), "x={0}, y={1}".format(x,y))

x= input("asd")
y= input("asd")
z= input("asd")
k= input("asd")
j= input("asd")


print("오늘은 {0}에서 야구경기가 열렸습니다.\n{1}와 {2}시합 {3}의 활약 \n{1}가 {2}를 {4}로 승리".format(x,y,z,k,j))
# Out:
# 오늘은 {0}에서 야구경기가 열렸습니다.{1}와 {2}시합bnm의 활약 zxc가 qwe를 1:1로 승리

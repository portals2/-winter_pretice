# %%
#리스트
a = []
a.append("a")
print(a)
a.append("b")
print(a)
a =a + ["c"]
print(a)
print("------------")
b = ["사과", "딸기", "멜론"]
k = input("과일")
j = 0
for i in range(3):
    if(b[i] == k):
        j = 1
        
if(j == 1):
    print("good")
else:
    print("no")

# %%
l = [["n", 7], ["k", 6], ["j", 3]]
print(len(l))
print(l[0][0])
max_1 = max(i[1] for i in l) #리스트 l의 1번째 인덱스만을 비교, 해당 속성 콜 

#리스트 l의 1번째 인덱스만을 비교, 해당 리스트 콜
for i in range(len(l)):
    if(l[i][1] == max_1):
        print(l[i])

print(max_1)

# %%
s = 5
b = 6
i = 7

p = [s, b, i]

for i in p:
    print(i, "----")

d = 8

p.append(d)

print(max(p))
print(min(p))

a = 0
for i in p:
    a += i
print(a / len(p))

# %%
p = ["s", 9755, "b", 7334, "d", 5783]

print(p[1])
print(p[5])
print(p[0::2])
a = 0
for i in p[1::2]:
    a += i
print(a)
print("-------")

t = [1,2,3,4,5,6,7]
t[2] = 4
print(t)
t[2:4] = [132, "z"]
print(t)
t.insert(6, "g")
print(t)
print("-------")
t.remove("g")
print(t)
t.pop()
print(t)
del(t[0])
print(t)

# %%
import random

q = []
q.append('b')
q.append('a')
q.append('c')

print("오늘의")
p = random.choice(q)
print(p)
k = input('aa')
q.append(k)
print(k, "k등록")
print(q)

kk = input("삭제하고픈")
q.remove(kk)
print(q)

# %%
c = [('s', 1), ('b', 2), ('i', 3)]
p_=0
for i in range(len(c)):
    max_c = max(i[1] for i in c) #0[1], 1[2]... 순으로 바뀌고 비교
    min_c = min(i[1] for i in c)
    p_ += c[i][1]

print(max_c)
print(min_c)
print(p_ / len(c))

# %%
a = ["apple", "banana", 'kiwi', 'melon', 'mango']
a_ = [] #길이 리스트
a1 = [] #가장긴 리스트
s = 0

for i in range(len(a)):
    if(len(a1) == 0):
        for j in range(len(a)):
            a_.append(len(a[j]))
    if(len(a[i]) == max(a_)):
        a1.append(max(a_))
    else:
        a1.append(0)


for i in range(len(a)):
    if(len(a[i]) == a1[i]):
        print(a[i])
        


for i in range(len(a)):
    if(a1[i] > 0):
        a.remove(a[s])
        s = s - 1
    s = s + 1
#print(a[a_.index(a1)]) #a_ 의 max값의 인덱스를 구해서 a의 인덱스로 참조
# del a[a_.index(a1)]

print(a)

print('-----------------')

print(a_)

print('-----------------')

i_ = "melon"

for j in range(len(a)):
    if(a[j] == i_):
        print(a.index(a[j]))

# %%
#딕셔너리
p_b = {'홍길동':'010-132-456'}
p_b['아무개'] = '010-987654'
p_b['그사람'] = '010-65498731'
print(p_b)

# print(p_b.keys())
# print(p_b.values())
# print(p_b.items())

for name, p_n in p_b.items():
    print(name, ':', p_n)

sort_p_b = sorted(p_b.items()) #sort 사용시 리스트로 변환됨
print(type(p_b))
print(type(sort_p_b)) 
sort_p_b = dict(sorted(p_b.items(), key=lambda x: x[0])) #다시 딕셔너리로 변환
print(type(p_b))
print(type(sort_p_b))


for name, p_n in sort_p_b.items():
    print(name, ':', p_n)
# Out:
# {'홍길동': '010-132-456', '아무개': '010-987654', '그사람': '010-65498731'}
# 홍길동 : 010-132-456
# 아무개 : 010-987654
# 그사람 : 010-65498731
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# <class 'dict'>
# 그사람 : 010-65498731
# 아무개 : 010-987654
# 홍길동 : 010-132-456

# %%
# item= {'co':7, 'pen':3, 'cup':0, 'milk':4}
# ff = 0
# em = 1
    
# while(True):
#     p_= int(input('구매(1) or (0)'))
#     i_ = input('제품')
#     n_ = int(input('수'))
    
#     if(p_ == em):
#         item[i_] = item[i_] - n_
#         print(item[i_])
#         if(item[i_] == 0):
#             print('채')
#     elif(p_ == ff):
#         item[i_] = item[i_] + n_
#         print(item[i_])

kor = ['커피', '펜', '종이컵', '우유']
eng = ['co', 'pen', 'cup', 'milk']
value = [7, 3, 8, 2]

i_kor = {}
i_eng = {}

for i in range(len(value)):
    i_kor[kor[i]] = value[i]
    i_eng[eng[i]] = value[i]

lan = input('k or e')
while(True):
    if(lan == 'k'):
        user_in = int(input('1,2,3,4'))
        if(user_in == 1):
            for p_name, stock in i_kor.items():
                print(p_name, ':', stock)
        elif(user_in == 2):
            for p_name, stock in i_kor.items():
                print(p_name, ':', stock)
            i_name = input("이름")
            cell = int(input('수'))
            if (i_kor[i_name] > cell):
                i_kor[i_name] -= cell
            else:
                print('없음')
        elif(user_in == 3):
            for p_name, stock in i_kor.items():
                print(p_name, ':', stock)
            i_name = input("이름")
            cell = int(input('수'))
            i_kor[i_name] += cell
        elif(user_in ==4):
            print('종료')
            break
        else:
            print('wrong')
            break
# Out:
# wrong
